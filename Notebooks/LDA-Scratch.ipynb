# %%
import numpy as np
from scipy.special import digamma, gammaln

# %%
def get_words_from_doc(doc):
    #return np.array(doc.split())
    return np.array(doc)
    
def word_pos_in_doc(words, word):
    bool_indicator = np.in1d(words, word)
    #vocab_idx = np.where(vocabulary == word)
    return bool_indicator.astype(int) 

def word_pos_in_vocab(vocabulary, word):
    #bool_indicator = np.in1d(words, word)
    vocab_idx = np.where(vocabulary == word)
    return vocab_idx 
    
def initialize_parameters(documents, vocabulary, k, M):
    Phi = []
    gamma = np.zeros([M,k])
    alpha = np.ones([M,k])
    for m in range(0,M):
        doc = get_words_from_doc(documents[m])
        N = len(doc)
        phi = np.ones([N,k]) * 1/float(k)
        for i in range(0,k):
            gamma[m, i] = alpha[m, i] + N/float(k)
        Phi.append(phi)
        m += 1
    # Initialize Beta
    Beta = np.zeros([k,len(vocabulary)])
    for i in range(0,k):
        tmp = np.random.uniform(0, 1, len(vocabulary))
        Beta[i,:] = tmp / np.sum(tmp)
    return Phi, gamma, alpha, Beta
                
    
def compute_likelihood(Phi, gamma, alpha, Beta, document, vocabulary, k):
    likelihood = 0.0
    V = len(vocabulary)
    words = get_words_from_doc(document)
    N = len(words)
    
    alpha_sum = 0.0
    phi_gamma_sum = 0.0
    phi_logbeta_sum = 0.0
    entropy_sum = 0.0
    gamma_sum = 0.0
    
    alpha_sum += gammaln(np.sum(alpha))  
    gamma_sum -= gammaln(np.sum(gamma)) 
    for i in range(0,k):
        alpha_sum += -gammaln(alpha[i]) + \
                (alpha[i] - 1) * (digamma(gamma[i]) - digamma(np.sum(gamma)))
        
        for n in range(0,N):
            if Phi[n,i] > 0:
                w_indicator = np.sum(np.in1d(vocabulary, words[n]))   
                phi_gamma_sum += Phi[n,i] * (digamma(gamma[i]) - digamma(np.sum(gamma[:])))
                entropy_sum += Phi[n,i] * np.log(Phi[n,i])
                for j in range(0,V):
                    if Beta[i,j] > 0:
                        phi_logbeta_sum += Phi[n,i] * w_indicator * np.log(Beta[i,j])
            
        gamma_sum += gammaln(gamma[i]) - \
                    (gamma[i] - 1) * (digamma(gamma[i]) - digamma(np.sum(gamma[:])))
    
    likelihood += (alpha_sum + phi_gamma_sum + phi_logbeta_sum - gamma_sum - entropy_sum) 
    return likelihood

def E_step(Phi, gamma, alpha, Beta, documents, vocabulary, k, M):
    print('E-step')
    likelihood = 0.0
    convergence_indicator = np.zeros(M)
    for d in range(0,M):
        words = get_words_from_doc(documents[d])
        N = len(words)
        phi = Phi[d]
        
        conv_counter = 0
        while convergence_indicator[d] == 0 and d < len(convergence_indicator):
            
            phi_old = phi
            phi = np.zeros([N,k])
            gamma_old = gamma[d, :]
            
            for n in range(0,N):
                word = words[n]
                vocab_idx = word_pos_in_vocab(vocabulary, word)
                if len(vocab_idx[0]) > 0: # word does not exist in vocabulary
                    for i in range(0,k):                
                        beta = Beta[i, vocab_idx]
                        phi[n, i] = beta[0][0] * np.exp(digamma(gamma[d,i]) - digamma(np.sum(gamma[d,:])))
                    phi[n,:] = phi[n,:] / np.sum(phi[n,:])   
            gamma[d, :] = alpha[d, :] + np.sum(phi, axis=0)    
            
            conv_counter += 1
            # Check if gamma and phi converged
            if np.linalg.norm(phi - phi_old) < 1e-3 and np.linalg.norm(gamma[d,:] - gamma_old) < 1e-3:
                convergence_indicator[d] = 1
                Phi[d] = phi               
                print('Document ' + str(d) + ' needed ' + str(conv_counter) + ' iterations to converge.')
                
                likelihood += compute_likelihood(Phi[d], gamma[d,:], alpha[d,:], Beta, documents[d], vocabulary, k)
                
    return Phi, gamma, likelihood
    
def M_step(Phi, gamma, alpha, documents, vocabulary, k, M):
    print('M-step')
    V = len(vocabulary)
    
    Beta = np.zeros([k,V])
    for d in range(0,M):
        words = get_words_from_doc(documents[d])
        Phi_d = Phi[d]
        for i in range(0,k):
            phi = Phi_d[:,i]
            for j in range(0,V):
                word = vocabulary[j]
                indicator = word_pos_in_doc(words, word)
                Beta[i,j] += np.dot(indicator, phi)
    Beta = np.transpose(np.transpose(Beta) / np.sum(Beta, axis=1))
    
    alpha_new = alpha
    return alpha_new, Beta
    
def variational_EM(Phi_init, gamma_init, alpha_init, Beta_init, documents, vocabulary, k, M):
    print('Variational EM')
    likelihood = 0
    likelihood_old = 0
    iteration = 1 # Initialization step is the first step
    Phi= Phi_init
    gamma = gamma_init
    alpha = alpha_init
    Beta = Beta_init
    while iteration <= 2 or np.abs((likelihood-likelihood_old)/likelihood_old) > 1e-4:
        # Update parameters 
        likelihood_old = likelihood
        Phi_old = Phi 
        gamma_old = gamma 
        alpha_old = alpha
        Beta_old = Beta
    
        Phi, gamma, likelihood = \
            E_step(Phi_old, gamma_old, alpha_old, Beta_old, documents, vocabulary, k, M)
        alpha, Beta = \
            M_step(Phi, gamma, alpha_old, documents, vocabulary, k, M)
                
        print('Iteration ' + str(iteration) + ': Likelihood = ' + str(likelihood))
        iteration += 1
        
        if iteration > 100:
            break
        
    return Phi, gamma, alpha, Beta, likelihood

# %%
from google.colab import files
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd
import nltk

# %%
df = pd.read_csv("amzn_food_cleansed_stemmed_100k.csv")

# %%
voc = list(set([word for word in doc.split()]) for doc in df["Cleansed"])
docs = [doc.split() for doc in df["Cleansed"].to_list()]

# %%
M=1000  #len(docs)
k = 4          # nbr of latent states z

Phi_init, gamma_init, alpha_init, Beta_init = initialize_parameters(docs, voc, k, M)

Phi, gamma, alpha, Beta, likelihood = \
    variational_EM(Phi_init, gamma_init, alpha_init, Beta_init, docs, voc, k, M)
# Out:
# Variational EM
# E-step
# Document 0 needed 2 iterations to converge.
# Document 1 needed 2 iterations to converge.
# Document 2 needed 2 iterations to converge.
# Document 3 needed 2 iterations to converge.
# Document 4 needed 2 iterations to converge.
# Document 5 needed 2 iterations to converge.
# Document 6 needed 2 iterations to converge.
# Document 7 needed 2 iterations to converge.
# Document 8 needed 2 iterations to converge.
# Document 9 needed 2 iterations to converge.
# Document 10 needed 2 iterations to converge.
# Document 11 needed 2 iterations to converge.
# Document 12 needed 2 iterations to converge.
# Document 13 needed 2 iterations to converge.
# Document 14 needed 2 iterations to converge.
# Document 15 needed 2 iterations to converge.
# Document 16 needed 2 iterations to converge.
# Document 17 needed 2 iterations to converge.
# Document 18 needed 2 iterations to converge.
# Document 19 needed 2 iterations to converge.
# Document 20 needed 2 iterations to converge.
# Document 21 needed 2 iterations to converge.
# Document 22 needed 2 iterations to converge.
# Document 23 needed 2 iterations to converge.
# Document 24 needed 2 iterations to converge.
# Document 25 needed 2 iterations to converge.
# Document 26 needed 2 iterations to converge.
# Document 27 needed 2 iterations to converge.
# Document 28 needed 2 iterations to converge.
# Document 29 needed 2 iterations to converge.
# Document 30 needed 2 iterations to converge.
# Document 31 needed 2 iterations to converge.
# Document 32 needed 2 iterations to converge.
# Document 33 needed 2 iterations to converge.
# Document 34 needed 2 iterations to converge.
# Document 35 needed 2 iterations to converge.
# Document 36 needed 2 iterations to converge.
# Document 37 needed 2 iterations to converge.
# Document 38 needed 2 iterations to converge.
# Document 39 needed 2 iterations to converge.
# Document 40 needed 2 iterations to converge.
# Document 41 needed 2 iterations to converge.
# Document 42 needed 2 iterations to converge.
# Document 43 needed 2 iterations to converge.
# Document 44 needed 2 iterations to converge.
# Document 45 needed 2 iterations to converge.
# Document 46 needed 2 iterations to converge.
# Document 47 needed 2 iterations to converge.
# Document 48 needed 2 iterations to converge.
# Document 49 needed 2 iterations to converge.
# Document 50 needed 2 iterations to converge.
# Document 51 needed 2 iterations to converge.
# Document 52 needed 2 iterations to converge.
# Document 53 needed 2 iterations to converge.
# Document 54 needed 2 iterations to converge.
# Document 55 needed 2 iterations to converge.
# Document 56 needed 2 iterations to converge.
# Document 57 needed 2 iterations to converge.
# Document 58 needed 2 iterations to converge.
# Document 59 needed 2 iterations to converge.
# Document 60 needed 2 iterations to converge.
# Document 61 needed 2 iterations to converge.
# Document 62 needed 2 iterations to converge.
# Document 63 needed 2 iterations to converge.
# Document 64 needed 2 iterations to converge.
# Document 65 needed 2 iterations to converge.
# Document 66 needed 2 iterations to converge.
# Document 67 needed 2 iterations to converge.
# Document 68 needed 2 iterations to converge.
# Document 69 needed 2 iterations to converge.
# Document 70 needed 2 iterations to converge.
# Document 71 needed 2 iterations to converge.
# Document 72 needed 2 iterations to converge.
# Document 73 needed 2 iterations to converge.
# Document 74 needed 2 iterations to converge.
# Document 75 needed 2 iterations to converge.
# Document 76 needed 2 iterations to converge.
# Document 77 needed 2 iterations to converge.
# Document 78 needed 2 iterations to converge.
# Document 79 needed 2 iterations to converge.
# Document 80 needed 2 iterations to converge.
# Document 81 needed 2 iterations to converge.
# Document 82 needed 2 iterations to converge.
# Document 83 needed 2 iterations to converge.
# Document 84 needed 2 iterations to converge.
# Document 85 needed 2 iterations to converge.
# Document 86 needed 2 iterations to converge.
# Document 87 needed 2 iterations to converge.
# Document 88 needed 2 iterations to converge.
# Document 89 needed 2 iterations to converge.
# Document 90 needed 2 iterations to converge.
# Document 91 needed 2 iterations to converge.
# Document 92 needed 2 iterations to converge.
# Document 93 needed 2 iterations to converge.
# Document 94 needed 2 iterations to converge.
# Document 95 needed 2 iterations to converge.
# Document 96 needed 2 iterations to converge.
# Document 97 needed 2 iterations to converge.
# Document 98 needed 2 iterations to converge.
# Document 99 needed 2 iterations to converge.
# Document 100 needed 2 iterations to converge.
# Document 101 needed 2 iterations to converge.
# Document 102 needed 2 iterations to converge.
# Document 103 needed 2 iterations to converge.
# Document 104 needed 2 iterations to converge.
# Document 105 needed 2 iterations to converge.
# Document 106 needed 2 iterations to converge.
# Document 107 needed 2 iterations to converge.
# Document 108 needed 2 iterations to converge.
# Document 109 needed 2 iterations to converge.
# Document 110 needed 2 iterations to converge.
# Document 111 needed 2 iterations to converge.
# Document 112 needed 2 iterations to converge.
# Document 113 needed 2 iterations to converge.
# Document 114 needed 2 iterations to converge.
# Document 115 needed 2 iterations to converge.
# Document 116 needed 2 iterations to converge.
# Document 117 needed 2 iterations to converge.
# Document 118 needed 2 iterations to converge.
# Document 119 needed 2 iterations to converge.
# Document 120 needed 2 iterations to converge.
# Document 121 needed 2 iterations to converge.
# Document 122 needed 2 iterations to converge.
# Document 123 needed 2 iterations to converge.
# Document 124 needed 2 iterations to converge.
# Document 125 needed 2 iterations to converge.
# Document 126 needed 2 iterations to converge.
# Document 127 needed 2 iterations to converge.
# Document 128 needed 2 iterations to converge.
# Document 129 needed 2 iterations to converge.
# Document 130 needed 2 iterations to converge.
# Document 131 needed 2 iterations to converge.
# Document 132 needed 2 iterations to converge.
# Document 133 needed 2 iterations to converge.
# Document 134 needed 2 iterations to converge.
# Document 135 needed 2 iterations to converge.
# Document 136 needed 2 iterations to converge.
# Document 137 needed 2 iterations to converge.
# Document 138 needed 2 iterations to converge.
# Document 139 needed 2 iterations to converge.
# Document 140 needed 2 iterations to converge.
# Document 141 needed 2 iterations to converge.
# Document 142 needed 2 iterations to converge.
# Document 143 needed 2 iterations to converge.
# Document 144 needed 2 iterations to converge.
# Document 145 needed 2 iterations to converge.
# Document 146 needed 2 iterations to converge.
# Document 147 needed 2 iterations to converge.
# Document 148 needed 2 iterations to converge.
# Document 149 needed 2 iterations to converge.
# Document 150 needed 2 iterations to converge.
# Document 151 needed 2 iterations to converge.
# Document 152 needed 2 iterations to converge.
# Document 153 needed 2 iterations to converge.
# Document 154 needed 2 iterations to converge.
# Document 155 needed 2 iterations to converge.
# Document 156 needed 2 iterations to converge.
# Document 157 needed 2 iterations to converge.
# Document 158 needed 2 iterations to converge.
# Document 159 needed 2 iterations to converge.
# Document 160 needed 2 iterations to converge.
# Document 161 needed 2 iterations to converge.
# Document 162 needed 2 iterations to converge.
# Document 163 needed 2 iterations to converge.
# Document 164 needed 2 iterations to converge.
# Document 165 needed 2 iterations to converge.
# Document 166 needed 2 iterations to converge.
# Document 167 needed 2 iterations to converge.
# Document 168 needed 2 iterations to converge.
# Document 169 needed 2 iterations to converge.
# Document 170 needed 2 iterations to converge.
# Document 171 needed 2 iterations to converge.
# Document 172 needed 2 iterations to converge.
# Document 173 needed 2 iterations to converge.
# Document 174 needed 2 iterations to converge.
# Document 175 needed 2 iterations to converge.
# Document 176 needed 2 iterations to converge.
# Document 177 needed 2 iterations to converge.
# Document 178 needed 2 iterations to converge.
# Document 179 needed 2 iterations to converge.
# Document 180 needed 2 iterations to converge.
# Document 181 needed 2 iterations to converge.
# Document 182 needed 2 iterations to converge.
# Document 183 needed 2 iterations to converge.
# Document 184 needed 2 iterations to converge.
# Document 185 needed 2 iterations to converge.
# Document 186 needed 2 iterations to converge.
# Document 187 needed 2 iterations to converge.
# Document 188 needed 2 iterations to converge.
# Document 189 needed 2 iterations to converge.
# Document 190 needed 2 iterations to converge.
# Document 191 needed 2 iterations to converge.
# Document 192 needed 2 iterations to converge.
# Document 193 needed 2 iterations to converge.
# Document 194 needed 2 iterations to converge.
# Document 195 needed 2 iterations to converge.
# Document 196 needed 2 iterations to converge.
# Document 197 needed 2 iterations to converge.
# Document 198 needed 2 iterations to converge.
# Document 199 needed 2 iterations to converge.
# Document 200 needed 2 iterations to converge.
# Document 201 needed 2 iterations to converge.
# Document 202 needed 2 iterations to converge.
# Document 203 needed 2 iterations to converge.
# Document 204 needed 2 iterations to converge.
# Document 205 needed 2 iterations to converge.
# Document 206 needed 2 iterations to converge.
# Document 207 needed 2 iterations to converge.
# Document 208 needed 2 iterations to converge.
# Document 209 needed 2 iterations to converge.
# Document 210 needed 2 iterations to converge.
# Document 211 needed 2 iterations to converge.
# Document 212 needed 2 iterations to converge.
# Document 213 needed 2 iterations to converge.
# Document 214 needed 2 iterations to converge.
# Document 215 needed 2 iterations to converge.
# Document 216 needed 2 iterations to converge.
# Document 217 needed 2 iterations to converge.
# Document 218 needed 2 iterations to converge.
# Document 219 needed 2 iterations to converge.
# Document 220 needed 2 iterations to converge.
# Document 221 needed 2 iterations to converge.
# Document 222 needed 2 iterations to converge.
# Document 223 needed 2 iterations to converge.
# Document 224 needed 2 iterations to converge.
# Document 225 needed 2 iterations to converge.
# Document 226 needed 2 iterations to converge.
# Document 227 needed 2 iterations to converge.
# Document 228 needed 2 iterations to converge.
# Document 229 needed 2 iterations to converge.
# Document 230 needed 2 iterations to converge.
# Document 231 needed 2 iterations to converge.
# Document 232 needed 2 iterations to converge.
# Document 233 needed 2 iterations to converge.
# Document 234 needed 2 iterations to converge.
# Document 235 needed 2 iterations to converge.
# Document 236 needed 2 iterations to converge.
# Document 237 needed 2 iterations to converge.
# Document 238 needed 2 iterations to converge.
# Document 239 needed 2 iterations to converge.
# Document 240 needed 2 iterations to converge.
# Document 241 needed 2 iterations to converge.
# Document 242 needed 2 iterations to converge.
# Document 243 needed 2 iterations to converge.
# Document 244 needed 2 iterations to converge.
# Document 245 needed 2 iterations to converge.
# Document 246 needed 2 iterations to converge.
# Document 247 needed 2 iterations to converge.
# Document 248 needed 2 iterations to converge.
# Document 249 needed 2 iterations to converge.
# Document 250 needed 2 iterations to converge.
# Document 251 needed 2 iterations to converge.
# Document 252 needed 2 iterations to converge.
# Document 253 needed 2 iterations to converge.
# Document 254 needed 2 iterations to converge.
# Document 255 needed 2 iterations to converge.
# Document 256 needed 2 iterations to converge.
# Document 257 needed 2 iterations to converge.
# Document 258 needed 2 iterations to converge.
# Document 259 needed 2 iterations to converge.
# Document 260 needed 2 iterations to converge.
# Document 261 needed 2 iterations to converge.
# Document 262 needed 2 iterations to converge.
# Document 263 needed 2 iterations to converge.
# Document 264 needed 2 iterations to converge.
# Document 265 needed 2 iterations to converge.
# Document 266 needed 2 iterations to converge.
# Document 267 needed 2 iterations to converge.
# Document 268 needed 2 iterations to converge.
# Document 269 needed 2 iterations to converge.
# Document 270 needed 2 iterations to converge.
# Document 271 needed 2 iterations to converge.
# Document 272 needed 2 iterations to converge.
# Document 273 needed 2 iterations to converge.
# Document 274 needed 2 iterations to converge.
# Document 275 needed 2 iterations to converge.
# Document 276 needed 2 iterations to converge.
# Document 277 needed 2 iterations to converge.
# Document 278 needed 2 iterations to converge.
# Document 279 needed 2 iterations to converge.
# Document 280 needed 2 iterations to converge.
# Document 281 needed 2 iterations to converge.
# Document 282 needed 2 iterations to converge.
# Document 283 needed 2 iterations to converge.
# Document 284 needed 2 iterations to converge.
# Document 285 needed 2 iterations to converge.
# Document 286 needed 2 iterations to converge.
# Document 287 needed 2 iterations to converge.
# Document 288 needed 2 iterations to converge.
# Document 289 needed 2 iterations to converge.
# Document 290 needed 2 iterations to converge.
# Document 291 needed 2 iterations to converge.
# Document 292 needed 2 iterations to converge.
# Document 293 needed 2 iterations to converge.
# Document 294 needed 2 iterations to converge.
# Document 295 needed 2 iterations to converge.
# Document 296 needed 2 iterations to converge.
# Document 297 needed 2 iterations to converge.
# Document 298 needed 2 iterations to converge.
# Document 299 needed 2 iterations to converge.
# Document 300 needed 2 iterations to converge.
# Document 301 needed 2 iterations to converge.
# Document 302 needed 2 iterations to converge.
# Document 303 needed 2 iterations to converge.
# Document 304 needed 2 iterations to converge.
# Document 305 needed 2 iterations to converge.
# Document 306 needed 2 iterations to converge.
# Document 307 needed 2 iterations to converge.
# Document 308 needed 2 iterations to converge.
# Document 309 needed 2 iterations to converge.
# Document 310 needed 2 iterations to converge.
# Document 311 needed 2 iterations to converge.
# Document 312 needed 2 iterations to converge.
# Document 313 needed 2 iterations to converge.
# Document 314 needed 2 iterations to converge.
# Document 315 needed 2 iterations to converge.
# Document 316 needed 2 iterations to converge.
# Document 317 needed 2 iterations to converge.
# Document 318 needed 2 iterations to converge.
# Document 319 needed 2 iterations to converge.
# Document 320 needed 2 iterations to converge.
# Document 321 needed 2 iterations to converge.
# Document 322 needed 2 iterations to converge.
# Document 323 needed 2 iterations to converge.
# Document 324 needed 2 iterations to converge.
# Document 325 needed 2 iterations to converge.
# Document 326 needed 2 iterations to converge.
# Document 327 needed 2 iterations to converge.
# Document 328 needed 2 iterations to converge.
# Document 329 needed 2 iterations to converge.
# Document 330 needed 2 iterations to converge.
# Document 331 needed 2 iterations to converge.
# Document 332 needed 2 iterations to converge.
# Document 333 needed 2 iterations to converge.
# Document 334 needed 2 iterations to converge.
# Document 335 needed 2 iterations to converge.
# Document 336 needed 2 iterations to converge.
# Document 337 needed 2 iterations to converge.
# Document 338 needed 2 iterations to converge.
# Document 339 needed 2 iterations to converge.
# Document 340 needed 2 iterations to converge.
# Document 341 needed 2 iterations to converge.
# Document 342 needed 2 iterations to converge.
# Document 343 needed 2 iterations to converge.
# Document 344 needed 2 iterations to converge.
# Document 345 needed 2 iterations to converge.
# Document 346 needed 2 iterations to converge.
# Document 347 needed 2 iterations to converge.
# Document 348 needed 2 iterations to converge.
# Document 349 needed 2 iterations to converge.
# Document 350 needed 2 iterations to converge.
# Document 351 needed 2 iterations to converge.
# Document 352 needed 2 iterations to converge.
# Document 353 needed 2 iterations to converge.
# Document 354 needed 2 iterations to converge.
# Document 355 needed 2 iterations to converge.
# Document 356 needed 2 iterations to converge.
# Document 357 needed 2 iterations to converge.
# Document 358 needed 2 iterations to converge.
# Document 359 needed 2 iterations to converge.
# Document 360 needed 2 iterations to converge.
# Document 361 needed 2 iterations to converge.
# Document 362 needed 2 iterations to converge.
# Document 363 needed 2 iterations to converge.
# Document 364 needed 2 iterations to converge.
# Document 365 needed 2 iterations to converge.
# Document 366 needed 2 iterations to converge.
# Document 367 needed 2 iterations to converge.
# Document 368 needed 2 iterations to converge.
# Document 369 needed 2 iterations to converge.
# Document 370 needed 2 iterations to converge.
# Document 371 needed 2 iterations to converge.
# Document 372 needed 2 iterations to converge.
# Document 373 needed 2 iterations to converge.
# Document 374 needed 2 iterations to converge.
# Document 375 needed 2 iterations to converge.
# Document 376 needed 2 iterations to converge.
# Document 377 needed 2 iterations to converge.
# Document 378 needed 2 iterations to converge.
# Document 379 needed 2 iterations to converge.
# Document 380 needed 2 iterations to converge.
# Document 381 needed 2 iterations to converge.
# Document 382 needed 2 iterations to converge.
# Document 383 needed 2 iterations to converge.
# Document 384 needed 2 iterations to converge.
# Document 385 needed 2 iterations to converge.
# Document 386 needed 2 iterations to converge.
# Document 387 needed 2 iterations to converge.
# Document 388 needed 2 iterations to converge.
# Document 389 needed 2 iterations to converge.
# Document 390 needed 2 iterations to converge.
# Document 391 needed 2 iterations to converge.
# Document 392 needed 2 iterations to converge.
# Document 393 needed 2 iterations to converge.
# Document 394 needed 2 iterations to converge.
# Document 395 needed 2 iterations to converge.
# Document 396 needed 2 iterations to converge.
# Document 397 needed 2 iterations to converge.
# Document 398 needed 2 iterations to converge.
# Document 399 needed 2 iterations to converge.
# Document 400 needed 2 iterations to converge.
# Document 401 needed 2 iterations to converge.
# Document 402 needed 2 iterations to converge.
# Document 403 needed 2 iterations to converge.
# Document 404 needed 2 iterations to converge.
# Document 405 needed 2 iterations to converge.
# Document 406 needed 2 iterations to converge.
# Document 407 needed 2 iterations to converge.
# Document 408 needed 2 iterations to converge.
# Document 409 needed 2 iterations to converge.
# Document 410 needed 2 iterations to converge.
# Document 411 needed 2 iterations to converge.
# Document 412 needed 2 iterations to converge.
# Document 413 needed 2 iterations to converge.
# Document 414 needed 2 iterations to converge.
# Document 415 needed 2 iterations to converge.
# Document 416 needed 2 iterations to converge.
# Document 417 needed 2 iterations to converge.
# Document 418 needed 2 iterations to converge.
# Document 419 needed 2 iterations to converge.
# Document 420 needed 2 iterations to converge.
# Document 421 needed 2 iterations to converge.
# Document 422 needed 2 iterations to converge.
# Document 423 needed 2 iterations to converge.
# Document 424 needed 2 iterations to converge.
# Document 425 needed 2 iterations to converge.
# Document 426 needed 2 iterations to converge.
# Document 427 needed 2 iterations to converge.
# Document 428 needed 2 iterations to converge.
# Document 429 needed 2 iterations to converge.
# Document 430 needed 2 iterations to converge.
# Document 431 needed 2 iterations to converge.
# Document 432 needed 2 iterations to converge.
# Document 433 needed 2 iterations to converge.
# Document 434 needed 2 iterations to converge.
# Document 435 needed 2 iterations to converge.
# Document 436 needed 2 iterations to converge.
# Document 437 needed 2 iterations to converge.
# Document 438 needed 2 iterations to converge.
# Document 439 needed 2 iterations to converge.
# Document 440 needed 2 iterations to converge.
# Document 441 needed 2 iterations to converge.
# Document 442 needed 2 iterations to converge.
# Document 443 needed 2 iterations to converge.
# Document 444 needed 2 iterations to converge.
# Document 445 needed 2 iterations to converge.
# Document 446 needed 2 iterations to converge.
# Document 447 needed 2 iterations to converge.
# Document 448 needed 2 iterations to converge.
# Document 449 needed 2 iterations to converge.
# Document 450 needed 2 iterations to converge.
# Document 451 needed 2 iterations to converge.
# Document 452 needed 2 iterations to converge.
# Document 453 needed 2 iterations to converge.
# Document 454 needed 2 iterations to converge.
# Document 455 needed 2 iterations to converge.
# Document 456 needed 2 iterations to converge.
# Document 457 needed 2 iterations to converge.
# Document 458 needed 2 iterations to converge.
# Document 459 needed 2 iterations to converge.
# Document 460 needed 2 iterations to converge.
# Document 461 needed 2 iterations to converge.
# Document 462 needed 2 iterations to converge.
# Document 463 needed 2 iterations to converge.
# Document 464 needed 2 iterations to converge.
# Document 465 needed 2 iterations to converge.
# Document 466 needed 2 iterations to converge.
# Document 467 needed 2 iterations to converge.
# Document 468 needed 2 iterations to converge.
# Document 469 needed 2 iterations to converge.
# Document 470 needed 2 iterations to converge.
# Document 471 needed 2 iterations to converge.
# Document 472 needed 2 iterations to converge.
# Document 473 needed 2 iterations to converge.
# Document 474 needed 2 iterations to converge.
# Document 475 needed 2 iterations to converge.
# Document 476 needed 2 iterations to converge.
# Document 477 needed 2 iterations to converge.
# Document 478 needed 2 iterations to converge.
# Document 479 needed 2 iterations to converge.
# Document 480 needed 2 iterations to converge.
# Document 481 needed 2 iterations to converge.
# Document 482 needed 2 iterations to converge.
# Document 483 needed 2 iterations to converge.
# Document 484 needed 2 iterations to converge.
# Document 485 needed 2 iterations to converge.
# Document 486 needed 2 iterations to converge.
# Document 487 needed 2 iterations to converge.
# Document 488 needed 2 iterations to converge.
# Document 489 needed 2 iterations to converge.
# Document 490 needed 2 iterations to converge.
# Document 491 needed 2 iterations to converge.
# Document 492 needed 2 iterations to converge.
# Document 493 needed 2 iterations to converge.
# Document 494 needed 2 iterations to converge.
# Document 495 needed 2 iterations to converge.
# Document 496 needed 2 iterations to converge.
# Document 497 needed 2 iterations to converge.
# Document 498 needed 2 iterations to converge.
# Document 499 needed 2 iterations to converge.
# Document 500 needed 2 iterations to converge.
# Document 501 needed 2 iterations to converge.
# Document 502 needed 2 iterations to converge.
# Document 503 needed 2 iterations to converge.
# Document 504 needed 2 iterations to converge.
# Document 505 needed 2 iterations to converge.
# Document 506 needed 2 iterations to converge.
# Document 507 needed 2 iterations to converge.
# Document 508 needed 2 iterations to converge.
# Document 509 needed 2 iterations to converge.
# Document 510 needed 2 iterations to converge.
# Document 511 needed 2 iterations to converge.
# Document 512 needed 2 iterations to converge.
# Document 513 needed 2 iterations to converge.
# Document 514 needed 2 iterations to converge.
# Document 515 needed 2 iterations to converge.
# Document 516 needed 2 iterations to converge.
# Document 517 needed 2 iterations to converge.
# Document 518 needed 2 iterations to converge.
# Document 519 needed 2 iterations to converge.
# Document 520 needed 2 iterations to converge.
# Document 521 needed 2 iterations to converge.
# Document 522 needed 2 iterations to converge.
# Document 523 needed 2 iterations to converge.
# Document 524 needed 2 iterations to converge.
# Document 525 needed 2 iterations to converge.
# Document 526 needed 2 iterations to converge.
# Document 527 needed 2 iterations to converge.
# Document 528 needed 2 iterations to converge.
# Document 529 needed 2 iterations to converge.
# Document 530 needed 2 iterations to converge.
# Document 531 needed 2 iterations to converge.
# Document 532 needed 2 iterations to converge.
# Document 533 needed 2 iterations to converge.
# Document 534 needed 2 iterations to converge.
# Document 535 needed 2 iterations to converge.
# Document 536 needed 2 iterations to converge.
# Document 537 needed 2 iterations to converge.
# Document 538 needed 2 iterations to converge.
# Document 539 needed 2 iterations to converge.
# Document 540 needed 2 iterations to converge.
# Document 541 needed 2 iterations to converge.
# Document 542 needed 2 iterations to converge.
# Document 543 needed 2 iterations to converge.
# Document 544 needed 2 iterations to converge.
# Document 545 needed 2 iterations to converge.
# Document 546 needed 2 iterations to converge.
# Document 547 needed 2 iterations to converge.
# Document 548 needed 2 iterations to converge.
# Document 549 needed 2 iterations to converge.
# Document 550 needed 2 iterations to converge.
# Document 551 needed 2 iterations to converge.
# Document 552 needed 2 iterations to converge.
# Document 553 needed 2 iterations to converge.
# Document 554 needed 2 iterations to converge.
# Document 555 needed 2 iterations to converge.
# Document 556 needed 2 iterations to converge.
# Document 557 needed 2 iterations to converge.
# Document 558 needed 2 iterations to converge.
# Document 559 needed 2 iterations to converge.
# Document 560 needed 2 iterations to converge.
# Document 561 needed 2 iterations to converge.
# Document 562 needed 2 iterations to converge.
# Document 563 needed 2 iterations to converge.
# Document 564 needed 2 iterations to converge.
# Document 565 needed 2 iterations to converge.
# Document 566 needed 2 iterations to converge.
# Document 567 needed 2 iterations to converge.
# Document 568 needed 2 iterations to converge.
# Document 569 needed 2 iterations to converge.
# Document 570 needed 2 iterations to converge.
# Document 571 needed 2 iterations to converge.
# Document 572 needed 2 iterations to converge.
# Document 573 needed 2 iterations to converge.
# Document 574 needed 2 iterations to converge.
# Document 575 needed 2 iterations to converge.
# Document 576 needed 2 iterations to converge.
# Document 577 needed 2 iterations to converge.
# Document 578 needed 2 iterations to converge.
# Document 579 needed 2 iterations to converge.
# Document 580 needed 2 iterations to converge.
# Document 581 needed 2 iterations to converge.
# Document 582 needed 2 iterations to converge.
# Document 583 needed 2 iterations to converge.
# Document 584 needed 2 iterations to converge.
# Document 585 needed 2 iterations to converge.
# Document 586 needed 2 iterations to converge.
# Document 587 needed 2 iterations to converge.
# Document 588 needed 2 iterations to converge.
# Document 589 needed 2 iterations to converge.
# Document 590 needed 2 iterations to converge.
# Document 591 needed 2 iterations to converge.
# Document 592 needed 2 iterations to converge.
# Document 593 needed 2 iterations to converge.
# Document 594 needed 2 iterations to converge.
# Document 595 needed 2 iterations to converge.
# Document 596 needed 2 iterations to converge.
# Document 597 needed 2 iterations to converge.
# Document 598 needed 2 iterations to converge.
# Document 599 needed 2 iterations to converge.
# Document 600 needed 2 iterations to converge.
# Document 601 needed 2 iterations to converge.
# Document 602 needed 2 iterations to converge.
# Document 603 needed 2 iterations to converge.
# Document 604 needed 2 iterations to converge.
# Document 605 needed 2 iterations to converge.
# Document 606 needed 2 iterations to converge.
# Document 607 needed 2 iterations to converge.
# Document 608 needed 2 iterations to converge.
# Document 609 needed 2 iterations to converge.
# Document 610 needed 2 iterations to converge.
# Document 611 needed 2 iterations to converge.
# Document 612 needed 2 iterations to converge.
# Document 613 needed 2 iterations to converge.
# Document 614 needed 2 iterations to converge.
# Document 615 needed 2 iterations to converge.
# Document 616 needed 2 iterations to converge.
# Document 617 needed 2 iterations to converge.
# Document 618 needed 2 iterations to converge.
# Document 619 needed 2 iterations to converge.
# Document 620 needed 2 iterations to converge.
# Document 621 needed 2 iterations to converge.
# Document 622 needed 2 iterations to converge.
# Document 623 needed 2 iterations to converge.
# Document 624 needed 2 iterations to converge.
# Document 625 needed 2 iterations to converge.
# Document 626 needed 2 iterations to converge.
# Document 627 needed 2 iterations to converge.
# Document 628 needed 2 iterations to converge.
# Document 629 needed 2 iterations to converge.
# Document 630 needed 2 iterations to converge.
# Document 631 needed 2 iterations to converge.
# Document 632 needed 2 iterations to converge.
# Document 633 needed 2 iterations to converge.
# Document 634 needed 2 iterations to converge.
# Document 635 needed 2 iterations to converge.
# Document 636 needed 2 iterations to converge.
# Document 637 needed 2 iterations to converge.
# Document 638 needed 2 iterations to converge.
# Document 639 needed 2 iterations to converge.
# Document 640 needed 2 iterations to converge.
# Document 641 needed 2 iterations to converge.
# Document 642 needed 2 iterations to converge.
# Document 643 needed 2 iterations to converge.
# Document 644 needed 2 iterations to converge.
# Document 645 needed 2 iterations to converge.
# Document 646 needed 2 iterations to converge.
# Document 647 needed 2 iterations to converge.
# Document 648 needed 2 iterations to converge.
# Document 649 needed 2 iterations to converge.
# Document 650 needed 2 iterations to converge.
# Document 651 needed 2 iterations to converge.
# Document 652 needed 2 iterations to converge.
# Document 653 needed 2 iterations to converge.
# Document 654 needed 2 iterations to converge.
# Document 655 needed 2 iterations to converge.
# Document 656 needed 2 iterations to converge.
# Document 657 needed 2 iterations to converge.
# Document 658 needed 2 iterations to converge.
# Document 659 needed 2 iterations to converge.
# Document 660 needed 2 iterations to converge.
# Document 661 needed 2 iterations to converge.
# Document 662 needed 2 iterations to converge.
# Document 663 needed 2 iterations to converge.
# Document 664 needed 2 iterations to converge.
# Document 665 needed 2 iterations to converge.
# Document 666 needed 2 iterations to converge.
# Document 667 needed 2 iterations to converge.
# Document 668 needed 2 iterations to converge.
# Document 669 needed 2 iterations to converge.
# Document 670 needed 2 iterations to converge.
# Document 671 needed 2 iterations to converge.
# Document 672 needed 2 iterations to converge.
# Document 673 needed 2 iterations to converge.
# Document 674 needed 2 iterations to converge.
# Document 675 needed 2 iterations to converge.
# Document 676 needed 2 iterations to converge.
# Document 677 needed 2 iterations to converge.
# Document 678 needed 2 iterations to converge.
# Document 679 needed 2 iterations to converge.
# Document 680 needed 2 iterations to converge.
# Document 681 needed 2 iterations to converge.
# Document 682 needed 2 iterations to converge.
# Document 683 needed 2 iterations to converge.
# Document 684 needed 2 iterations to converge.
# Document 685 needed 2 iterations to converge.
# Document 686 needed 2 iterations to converge.
# Document 687 needed 2 iterations to converge.
# Document 688 needed 2 iterations to converge.
# Document 689 needed 2 iterations to converge.
# Document 690 needed 2 iterations to converge.
# Document 691 needed 2 iterations to converge.
# Document 692 needed 2 iterations to converge.
# Document 693 needed 2 iterations to converge.
# Document 694 needed 2 iterations to converge.
# Document 695 needed 2 iterations to converge.
# Document 696 needed 2 iterations to converge.
# Document 697 needed 2 iterations to converge.
# Document 698 needed 2 iterations to converge.
# Document 699 needed 2 iterations to converge.
# Document 700 needed 2 iterations to converge.
# Document 701 needed 2 iterations to converge.
# Document 702 needed 2 iterations to converge.
# Document 703 needed 2 iterations to converge.
# Document 704 needed 2 iterations to converge.
# Document 705 needed 2 iterations to converge.
# Document 706 needed 2 iterations to converge.
# Document 707 needed 2 iterations to converge.
# Document 708 needed 2 iterations to converge.
# Document 709 needed 2 iterations to converge.
# Document 710 needed 2 iterations to converge.
# Document 711 needed 2 iterations to converge.
# Document 712 needed 2 iterations to converge.
# Document 713 needed 2 iterations to converge.
# Document 714 needed 2 iterations to converge.
# Document 715 needed 2 iterations to converge.
# Document 716 needed 2 iterations to converge.
# Document 717 needed 2 iterations to converge.
# Document 718 needed 2 iterations to converge.
# Document 719 needed 2 iterations to converge.
# Document 720 needed 2 iterations to converge.
# Document 721 needed 2 iterations to converge.
# Document 722 needed 2 iterations to converge.
# Document 723 needed 2 iterations to converge.
# Document 724 needed 2 iterations to converge.
# Document 725 needed 2 iterations to converge.
# Document 726 needed 2 iterations to converge.
# Document 727 needed 2 iterations to converge.
# Document 728 needed 2 iterations to converge.
# Document 729 needed 2 iterations to converge.
# Document 730 needed 2 iterations to converge.
# Document 731 needed 2 iterations to converge.
# Document 732 needed 2 iterations to converge.
# Document 733 needed 2 iterations to converge.
# Document 734 needed 2 iterations to converge.
# Document 735 needed 2 iterations to converge.
# Document 736 needed 2 iterations to converge.
# Document 737 needed 2 iterations to converge.
# Document 738 needed 2 iterations to converge.
# Document 739 needed 2 iterations to converge.
# Document 740 needed 2 iterations to converge.
# Document 741 needed 2 iterations to converge.
# Document 742 needed 2 iterations to converge.
# Document 743 needed 2 iterations to converge.
# Document 744 needed 2 iterations to converge.
# Document 745 needed 2 iterations to converge.
# Document 746 needed 2 iterations to converge.
# Document 747 needed 2 iterations to converge.
# Document 748 needed 2 iterations to converge.
# Document 749 needed 2 iterations to converge.
# Document 750 needed 2 iterations to converge.
# Document 751 needed 2 iterations to converge.
# Document 752 needed 2 iterations to converge.
# Document 753 needed 2 iterations to converge.
# Document 754 needed 2 iterations to converge.
# Document 755 needed 2 iterations to converge.
# Document 756 needed 2 iterations to converge.
# Document 757 needed 2 iterations to converge.
# Document 758 needed 2 iterations to converge.
# Document 759 needed 2 iterations to converge.
# Document 760 needed 2 iterations to converge.
# Document 761 needed 2 iterations to converge.
# Document 762 needed 2 iterations to converge.
# Document 763 needed 2 iterations to converge.
# Document 764 needed 2 iterations to converge.
# Document 765 needed 2 iterations to converge.
# Document 766 needed 2 iterations to converge.
# Document 767 needed 2 iterations to converge.
# Document 768 needed 2 iterations to converge.
# Document 769 needed 2 iterations to converge.
# Document 770 needed 2 iterations to converge.
# Document 771 needed 2 iterations to converge.
# Document 772 needed 2 iterations to converge.
# Document 773 needed 2 iterations to converge.
# Document 774 needed 2 iterations to converge.
# Document 775 needed 2 iterations to converge.
# Document 776 needed 2 iterations to converge.
# Document 777 needed 2 iterations to converge.
# Document 778 needed 2 iterations to converge.
# Document 779 needed 2 iterations to converge.
# Document 780 needed 2 iterations to converge.
# Document 781 needed 2 iterations to converge.
# Document 782 needed 2 iterations to converge.
# Document 783 needed 2 iterations to converge.
# Document 784 needed 2 iterations to converge.
# Document 785 needed 2 iterations to converge.
# Document 786 needed 2 iterations to converge.
# Document 787 needed 2 iterations to converge.
# Document 788 needed 2 iterations to converge.
# Document 789 needed 2 iterations to converge.
# Document 790 needed 2 iterations to converge.
# Document 791 needed 2 iterations to converge.
# Document 792 needed 2 iterations to converge.
# Document 793 needed 2 iterations to converge.
# Document 794 needed 2 iterations to converge.
# Document 795 needed 2 iterations to converge.
# Document 796 needed 2 iterations to converge.
# Document 797 needed 2 iterations to converge.
# Document 798 needed 2 iterations to converge.
# Document 799 needed 2 iterations to converge.
# Document 800 needed 2 iterations to converge.
# Document 801 needed 2 iterations to converge.
# Document 802 needed 2 iterations to converge.
# Document 803 needed 2 iterations to converge.
# Document 804 needed 2 iterations to converge.
# Document 805 needed 2 iterations to converge.
# Document 806 needed 2 iterations to converge.
# Document 807 needed 2 iterations to converge.
# Document 808 needed 2 iterations to converge.
# Document 809 needed 2 iterations to converge.
# Document 810 needed 2 iterations to converge.
# Document 811 needed 2 iterations to converge.
# Document 812 needed 2 iterations to converge.
# Document 813 needed 2 iterations to converge.
# Document 814 needed 2 iterations to converge.
# Document 815 needed 2 iterations to converge.
# Document 816 needed 2 iterations to converge.
# Document 817 needed 2 iterations to converge.
# Document 818 needed 2 iterations to converge.
# Document 819 needed 2 iterations to converge.
# Document 820 needed 2 iterations to converge.
# Document 821 needed 2 iterations to converge.
# Document 822 needed 2 iterations to converge.
# Document 823 needed 2 iterations to converge.
# Document 824 needed 2 iterations to converge.
# Document 825 needed 2 iterations to converge.
# Document 826 needed 2 iterations to converge.
# Document 827 needed 2 iterations to converge.
# Document 828 needed 2 iterations to converge.
# Document 829 needed 2 iterations to converge.
# Document 830 needed 2 iterations to converge.
# Document 831 needed 2 iterations to converge.
# Document 832 needed 2 iterations to converge.
# Document 833 needed 2 iterations to converge.
# Document 834 needed 2 iterations to converge.
# Document 835 needed 2 iterations to converge.
# Document 836 needed 2 iterations to converge.
# Document 837 needed 2 iterations to converge.
# Document 838 needed 2 iterations to converge.
# Document 839 needed 2 iterations to converge.
# Document 840 needed 2 iterations to converge.
# Document 841 needed 2 iterations to converge.
# Document 842 needed 2 iterations to converge.
# Document 843 needed 2 iterations to converge.
# Document 844 needed 2 iterations to converge.
# Document 845 needed 2 iterations to converge.
# Document 846 needed 2 iterations to converge.
# Document 847 needed 2 iterations to converge.
# Document 848 needed 2 iterations to converge.
# Document 849 needed 2 iterations to converge.
# Document 850 needed 2 iterations to converge.
# Document 851 needed 2 iterations to converge.
# Document 852 needed 2 iterations to converge.
# Document 853 needed 2 iterations to converge.
# Document 854 needed 2 iterations to converge.
# Document 855 needed 2 iterations to converge.
# Document 856 needed 2 iterations to converge.
# Document 857 needed 2 iterations to converge.
# Document 858 needed 2 iterations to converge.
# Document 859 needed 2 iterations to converge.
# Document 860 needed 2 iterations to converge.
# Document 861 needed 2 iterations to converge.
# Document 862 needed 2 iterations to converge.
# Document 863 needed 2 iterations to converge.
# Document 864 needed 2 iterations to converge.
# Document 865 needed 2 iterations to converge.
# Document 866 needed 2 iterations to converge.
# Document 867 needed 2 iterations to converge.
# Document 868 needed 2 iterations to converge.
# Document 869 needed 2 iterations to converge.
# Document 870 needed 2 iterations to converge.
# Document 871 needed 2 iterations to converge.
# Document 872 needed 2 iterations to converge.
# Document 873 needed 2 iterations to converge.
# Document 874 needed 2 iterations to converge.
# Document 875 needed 2 iterations to converge.
# Document 876 needed 2 iterations to converge.
# Document 877 needed 2 iterations to converge.
# Document 878 needed 2 iterations to converge.
# Document 879 needed 2 iterations to converge.
# Document 880 needed 2 iterations to converge.
# Document 881 needed 2 iterations to converge.
# Document 882 needed 2 iterations to converge.
# Document 883 needed 2 iterations to converge.
# Document 884 needed 2 iterations to converge.
# Document 885 needed 2 iterations to converge.
# Document 886 needed 2 iterations to converge.
# Document 887 needed 2 iterations to converge.
# Document 888 needed 2 iterations to converge.
# Document 889 needed 2 iterations to converge.
# Document 890 needed 2 iterations to converge.
# Document 891 needed 2 iterations to converge.
# Document 892 needed 2 iterations to converge.
# Document 893 needed 2 iterations to converge.
# Document 894 needed 2 iterations to converge.
# Document 895 needed 2 iterations to converge.
# Document 896 needed 2 iterations to converge.
# Document 897 needed 2 iterations to converge.
# Document 898 needed 2 iterations to converge.
# Document 899 needed 2 iterations to converge.
# Document 900 needed 2 iterations to converge.
# Document 901 needed 2 iterations to converge.
# Document 902 needed 2 iterations to converge.
# Document 903 needed 2 iterations to converge.
# Document 904 needed 2 iterations to converge.
# Document 905 needed 2 iterations to converge.
# Document 906 needed 2 iterations to converge.
# Document 907 needed 2 iterations to converge.
# Document 908 needed 2 iterations to converge.
# Document 909 needed 2 iterations to converge.
# Document 910 needed 2 iterations to converge.
# Document 911 needed 2 iterations to converge.
# Document 912 needed 2 iterations to converge.
# Document 913 needed 2 iterations to converge.
# Document 914 needed 2 iterations to converge.
# Document 915 needed 2 iterations to converge.
# Document 916 needed 2 iterations to converge.
# Document 917 needed 2 iterations to converge.
# Document 918 needed 2 iterations to converge.
# Document 919 needed 2 iterations to converge.
# Document 920 needed 2 iterations to converge.
# Document 921 needed 2 iterations to converge.
# Document 922 needed 2 iterations to converge.
# Document 923 needed 2 iterations to converge.
# Document 924 needed 2 iterations to converge.
# Document 925 needed 2 iterations to converge.
# Document 926 needed 2 iterations to converge.
# Document 927 needed 2 iterations to converge.
# Document 928 needed 2 iterations to converge.
# Document 929 needed 2 iterations to converge.
# Document 930 needed 2 iterations to converge.
# Document 931 needed 2 iterations to converge.
# Document 932 needed 2 iterations to converge.
# Document 933 needed 2 iterations to converge.
# Document 934 needed 2 iterations to converge.
# Document 935 needed 2 iterations to converge.
# Document 936 needed 2 iterations to converge.
# Document 937 needed 2 iterations to converge.
# Document 938 needed 2 iterations to converge.
# Document 939 needed 2 iterations to converge.
# Document 940 needed 2 iterations to converge.
# Document 941 needed 2 iterations to converge.
# Document 942 needed 2 iterations to converge.
# Document 943 needed 2 iterations to converge.
# Document 944 needed 2 iterations to converge.
# Document 945 needed 2 iterations to converge.
# Document 946 needed 2 iterations to converge.
# Document 947 needed 2 iterations to converge.
# Document 948 needed 2 iterations to converge.
# Document 949 needed 2 iterations to converge.
# Document 950 needed 2 iterations to converge.
# Document 951 needed 2 iterations to converge.
# Document 952 needed 2 iterations to converge.
# Document 953 needed 2 iterations to converge.
# Document 954 needed 2 iterations to converge.
# Document 955 needed 2 iterations to converge.
# Document 956 needed 2 iterations to converge.
# Document 957 needed 2 iterations to converge.
# Document 958 needed 2 iterations to converge.
# Document 959 needed 2 iterations to converge.
# Document 960 needed 2 iterations to converge.
# Document 961 needed 2 iterations to converge.
# Document 962 needed 2 iterations to converge.
# Document 963 needed 2 iterations to converge.
# Document 964 needed 2 iterations to converge.
# Document 965 needed 2 iterations to converge.
# Document 966 needed 2 iterations to converge.
# Document 967 needed 2 iterations to converge.
# Document 968 needed 2 iterations to converge.
# Document 969 needed 2 iterations to converge.
# Document 970 needed 2 iterations to converge.
# Document 971 needed 2 iterations to converge.
# Document 972 needed 2 iterations to converge.
# Document 973 needed 2 iterations to converge.
# Document 974 needed 2 iterations to converge.
# Document 975 needed 2 iterations to converge.
# Document 976 needed 2 iterations to converge.
# Document 977 needed 2 iterations to converge.
# Document 978 needed 2 iterations to converge.
# Document 979 needed 2 iterations to converge.
# Document 980 needed 2 iterations to converge.
# Document 981 needed 2 iterations to converge.
# Document 982 needed 2 iterations to converge.
# Document 983 needed 2 iterations to converge.
# Document 984 needed 2 iterations to converge.
# Document 985 needed 2 iterations to converge.
# Document 986 needed 2 iterations to converge.
# Document 987 needed 2 iterations to converge.
# Document 988 needed 2 iterations to converge.
# Document 989 needed 2 iterations to converge.
# Document 990 needed 2 iterations to converge.
# Document 991 needed 2 iterations to converge.
# Document 992 needed 2 iterations to converge.
# Document 993 needed 2 iterations to converge.
# Document 994 needed 2 iterations to converge.
# Document 995 needed 2 iterations to converge.
# Document 996 needed 2 iterations to converge.
# Document 997 needed 2 iterations to converge.
# Document 998 needed 2 iterations to converge.
# Document 999 needed 2 iterations to converge.
# M-step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:118: RuntimeWarning: invalid value encountered in true_divide
# Iteration 1: Likelihood = 3583.5189384561095
# E-step
# Document 0 needed 1 iterations to converge.
# Document 1 needed 1 iterations to converge.
# Document 2 needed 1 iterations to converge.
# Document 3 needed 1 iterations to converge.
# Document 4 needed 1 iterations to converge.
# Document 5 needed 1 iterations to converge.
# Document 6 needed 1 iterations to converge.
# Document 7 needed 1 iterations to converge.
# Document 8 needed 1 iterations to converge.
# Document 9 needed 1 iterations to converge.
# Document 10 needed 1 iterations to converge.
# Document 11 needed 1 iterations to converge.
# Document 12 needed 1 iterations to converge.
# Document 13 needed 1 iterations to converge.
# Document 14 needed 1 iterations to converge.
# Document 15 needed 1 iterations to converge.
# Document 16 needed 1 iterations to converge.
# Document 17 needed 1 iterations to converge.
# Document 18 needed 1 iterations to converge.
# Document 19 needed 1 iterations to converge.
# Document 20 needed 1 iterations to converge.
# Document 21 needed 1 iterations to converge.
# Document 22 needed 1 iterations to converge.
# Document 23 needed 1 iterations to converge.
# Document 24 needed 1 iterations to converge.
# Document 25 needed 1 iterations to converge.
# Document 26 needed 1 iterations to converge.
# Document 27 needed 1 iterations to converge.
# Document 28 needed 1 iterations to converge.
# Document 29 needed 1 iterations to converge.
# Document 30 needed 1 iterations to converge.
# Document 31 needed 1 iterations to converge.
# Document 32 needed 1 iterations to converge.
# Document 33 needed 1 iterations to converge.
# Document 34 needed 1 iterations to converge.
# Document 35 needed 1 iterations to converge.
# Document 36 needed 1 iterations to converge.
# Document 37 needed 1 iterations to converge.
# Document 38 needed 1 iterations to converge.
# Document 39 needed 1 iterations to converge.
# Document 40 needed 1 iterations to converge.
# Document 41 needed 1 iterations to converge.
# ...
# Document 654 needed 1 iterations to converge.
# Document 655 needed 1 iterations to converge.
# Document 656 needed 1 iterations to converge.
# Document 657 needed 1 iterations to converge.
# Document 658 needed 1 iterations to converge.
# Document 659 needed 1 iterations to converge.
# Document 660 needed 1 iterations to converge.
# Document 661 needed 1 iterations to converge.
# Document 662 needed 1 iterations to converge.
# Document 663 needed 1 iterations to converge.
# Document 664 needed 1 iterations to converge.
# Document 665 needed 1 iterations to converge.
# Document 666 needed 1 iterations to converge.
# Document 667 needed 1 iterations to converge.
# Document 668 needed 1 iterations to converge.
# Document 669 needed 1 iterations to converge.
# Document 670 needed 1 iterations to converge.
# Document 671 needed 1 iterations to converge.
# Document 672 needed 1 iterations to converge.
# Document 673 needed 1 iterations to converge.
# Document 674 needed 1 iterations to converge.
# Document 675 needed 1 iterations to converge.
# Document 676 needed 1 iterations to converge.
# Document 677 needed 1 iterations to converge.
# Document 678 needed 1 iterations to converge.
# Document 679 needed 1 iterations to converge.
# Document 680 needed 1 iterations to converge.
# Document 681 needed 1 iterations to converge.
# Document 682 needed 1 iterations to converge.
# Document 683 needed 1 iterations to converge.
# Document 684 needed 1 iterations to converge.
# Document 685 needed 1 iterations to converge.
# Document 686 needed 1 iterations to converge.
# Document 687 needed 1 iterations to converge.
# Document 688 needed 1 iterations to converge.
# Document 689 needed 1 iterations to converge.
# Document 690 needed 1 iterations to converge.
# Document 691 needed 1 iterations to converge.
# Document 692 needed 1 iterations to converge.
# Document 693 needed 1 iterations to converge.
# Document 694 needed 1 iterations to converge.
# Document 695 needed 1 iterations to converge.
# Document 696 needed 1 iterations to converge.
# Document 697 needed 1 iterations to converge.
# Document 698 needed 1 iterations to converge.
# Document 699 needed 1 iterations to converge.
# Document 700 needed 1 iterations to converge.
# Document 701 needed 1 iterations to converge.
# Document 702 needed 1 iterations to converge.
# Document 703 needed 1 iterations to converge.
# Document 704 needed 1 iterations to converge.
# Document 705 needed 1 iterations to converge.
# Document 706 needed 1 iterations to converge.
# Document 707 needed 1 iterations to converge.
# Document 708 needed 1 iterations to converge.
# Document 709 needed 1 iterations to converge.
# Document 710 needed 1 iterations to converge.
# Document 711 needed 1 iterations to converge.
# Document 712 needed 1 iterations to converge.
# Document 713 needed 1 iterations to converge.
# Document 714 needed 1 iterations to converge.
# Document 715 needed 1 iterations to converge.
# Document 716 needed 1 iterations to converge.
# Document 717 needed 1 iterations to converge.
# Document 718 needed 1 iterations to converge.
# Document 719 needed 1 iterations to converge.
# Document 720 needed 1 iterations to converge.
# Document 721 needed 1 iterations to converge.
# Document 722 needed 1 iterations to converge.
# Document 723 needed 1 iterations to converge.
# Document 724 needed 1 iterations to converge.
# Document 725 needed 1 iterations to converge.
# Document 726 needed 1 iterations to converge.
# Document 727 needed 1 iterations to converge.
# Document 728 needed 1 iterations to converge.
# Document 729 needed 1 iterations to converge.
# Document 730 needed 1 iterations to converge.
# Document 731 needed 1 iterations to converge.
# Document 732 needed 1 iterations to converge.
# Document 733 needed 1 iterations to converge.
# Document 734 needed 1 iterations to converge.
# Document 735 needed 1 iterations to converge.
# Document 736 needed 1 iterations to converge.
# Document 737 needed 1 iterations to converge.
# Document 738 needed 1 iterations to converge.
# Document 739 needed 1 iterations to converge.
# Document 740 needed 1 iterations to converge.
# Document 741 needed 1 iterations to converge.
# Document 742 needed 1 iterations to converge.
# Document 743 needed 1 iterations to converge.
# Document 744 needed 1 iterations to converge.
# Document 745 needed 1 iterations to converge.
# Document 746 needed 1 iterations to converge.
# Document 747 needed 1 iterations to converge.
# Document 748 needed 1 iterations to converge.
# Document 749 needed 1 iterations to converge.
# Document 750 needed 1 iterations to converge.
# Document 751 needed 1 iterations to converge.
# Document 752 needed 1 iterations to converge.
# Document 753 needed 1 iterations to converge.
# Document 754 needed 1 iterations to converge.
# Document 755 needed 1 iterations to converge.
# Document 756 needed 1 iterations to converge.
# Document 757 needed 1 iterations to converge.
# Document 758 needed 1 iterations to converge.
# Document 759 needed 1 iterations to converge.
# Document 760 needed 1 iterations to converge.
# Document 761 needed 1 iterations to converge.
# Document 762 needed 1 iterations to converge.
# Document 763 needed 1 iterations to converge.
# Document 764 needed 1 iterations to converge.
# Document 765 needed 1 iterations to converge.
# Document 766 needed 1 iterations to converge.
# Document 767 needed 1 iterations to converge.
# Document 768 needed 1 iterations to converge.
# Document 769 needed 1 iterations to converge.
# Document 770 needed 1 iterations to converge.
# Document 771 needed 1 iterations to converge.
# Document 772 needed 1 iterations to converge.
# Document 773 needed 1 iterations to converge.
# Document 774 needed 1 iterations to converge.
# Document 775 needed 1 iterations to converge.
# Document 776 needed 1 iterations to converge.
# Document 777 needed 1 iterations to converge.
# Document 778 needed 1 iterations to converge.
# Document 779 needed 1 iterations to converge.
# Document 780 needed 1 iterations to converge.
# Document 781 needed 1 iterations to converge.
# Document 782 needed 1 iterations to converge.
# Document 783 needed 1 iterations to converge.
# Document 784 needed 1 iterations to converge.
# Document 785 needed 1 iterations to converge.
# Document 786 needed 1 iterations to converge.
# Document 787 needed 1 iterations to converge.
# Document 788 needed 1 iterations to converge.
# Document 789 needed 1 iterations to converge.
# Document 790 needed 1 iterations to converge.
# Document 791 needed 1 iterations to converge.
# Document 792 needed 1 iterations to converge.
# Document 793 needed 1 iterations to converge.
# Document 794 needed 1 iterations to converge.
# Document 795 needed 1 iterations to converge.
# Document 796 needed 1 iterations to converge.
# Document 797 needed 1 iterations to converge.
# Document 798 needed 1 iterations to converge.
# Document 799 needed 1 iterations to converge.
# Document 800 needed 1 iterations to converge.
# Document 801 needed 1 iterations to converge.
# Document 802 needed 1 iterations to converge.
# Document 803 needed 1 iterations to converge.
# Document 804 needed 1 iterations to converge.
# Document 805 needed 1 iterations to converge.
# Document 806 needed 1 iterations to converge.
# Document 807 needed 1 iterations to converge.
# Document 808 needed 1 iterations to converge.
# Document 809 needed 1 iterations to converge.
# Document 810 needed 1 iterations to converge.
# Document 811 needed 1 iterations to converge.
# Document 812 needed 1 iterations to converge.
# Document 813 needed 1 iterations to converge.
# Document 814 needed 1 iterations to converge.
# Document 815 needed 1 iterations to converge.
# Document 816 needed 1 iterations to converge.
# Document 817 needed 1 iterations to converge.
# Document 818 needed 1 iterations to converge.
# Document 819 needed 1 iterations to converge.
# Document 820 needed 1 iterations to converge.
# Document 821 needed 1 iterations to converge.
# Document 822 needed 1 iterations to converge.
# Document 823 needed 1 iterations to converge.
# Document 824 needed 1 iterations to converge.
# Document 825 needed 1 iterations to converge.
# Document 826 needed 1 iterations to converge.
# Document 827 needed 1 iterations to converge.
# Document 828 needed 1 iterations to converge.
# Document 829 needed 1 iterations to converge.
# Document 830 needed 1 iterations to converge.
# Document 831 needed 1 iterations to converge.
# Document 832 needed 1 iterations to converge.
# Document 833 needed 1 iterations to converge.
# Document 834 needed 1 iterations to converge.
# Document 835 needed 1 iterations to converge.
# Document 836 needed 1 iterations to converge.
# Document 837 needed 1 iterations to converge.
# Document 838 needed 1 iterations to converge.
# Document 839 needed 1 iterations to converge.
# Document 840 needed 1 iterations to converge.
# Document 841 needed 1 iterations to converge.
# Document 842 needed 1 iterations to converge.
# Document 843 needed 1 iterations to converge.
# Document 844 needed 1 iterations to converge.
# Document 845 needed 1 iterations to converge.
# Document 846 needed 1 iterations to converge.
# Document 847 needed 1 iterations to converge.
# Document 848 needed 1 iterations to converge.
# Document 849 needed 1 iterations to converge.
# Document 850 needed 1 iterations to converge.
# Document 851 needed 1 iterations to converge.
# Document 852 needed 1 iterations to converge.
# Document 853 needed 1 iterations to converge.
# Document 854 needed 1 iterations to converge.
# Document 855 needed 1 iterations to converge.
# Document 856 needed 1 iterations to converge.
# Document 857 needed 1 iterations to converge.
# Document 858 needed 1 iterations to converge.
# Document 859 needed 1 iterations to converge.
# Document 860 needed 1 iterations to converge.
# Document 861 needed 1 iterations to converge.
# Document 862 needed 1 iterations to converge.
# Document 863 needed 1 iterations to converge.
# Document 864 needed 1 iterations to converge.
# Document 865 needed 1 iterations to converge.
# Document 866 needed 1 iterations to converge.
# Document 867 needed 1 iterations to converge.
# Document 868 needed 1 iterations to converge.
# Document 869 needed 1 iterations to converge.
# Document 870 needed 1 iterations to converge.
# Document 871 needed 1 iterations to converge.
# Document 872 needed 1 iterations to converge.
# Document 873 needed 1 iterations to converge.
# Document 874 needed 1 iterations to converge.
# Document 875 needed 1 iterations to converge.
# Document 876 needed 1 iterations to converge.
# Document 877 needed 1 iterations to converge.
# Document 878 needed 1 iterations to converge.
# Document 879 needed 1 iterations to converge.
# Document 880 needed 1 iterations to converge.
# Document 881 needed 1 iterations to converge.
# Document 882 needed 1 iterations to converge.
# Document 883 needed 1 iterations to converge.
# Document 884 needed 1 iterations to converge.
# Document 885 needed 1 iterations to converge.
# Document 886 needed 1 iterations to converge.
# Document 887 needed 1 iterations to converge.
# Document 888 needed 1 iterations to converge.
# Document 889 needed 1 iterations to converge.
# Document 890 needed 1 iterations to converge.
# Document 891 needed 1 iterations to converge.
# Document 892 needed 1 iterations to converge.
# Document 893 needed 1 iterations to converge.
# Document 894 needed 1 iterations to converge.
# Document 895 needed 1 iterations to converge.
# Document 896 needed 1 iterations to converge.
# Document 897 needed 1 iterations to converge.
# Document 898 needed 1 iterations to converge.
# Document 899 needed 1 iterations to converge.
# Document 900 needed 1 iterations to converge.
# Document 901 needed 1 iterations to converge.
# Document 902 needed 1 iterations to converge.
# Document 903 needed 1 iterations to converge.
# Document 904 needed 1 iterations to converge.
# Document 905 needed 1 iterations to converge.
# Document 906 needed 1 iterations to converge.
# Document 907 needed 1 iterations to converge.
# Document 908 needed 1 iterations to converge.
# Document 909 needed 1 iterations to converge.
# Document 910 needed 1 iterations to converge.
# Document 911 needed 1 iterations to converge.
# Document 912 needed 1 iterations to converge.
# Document 913 needed 1 iterations to converge.
# Document 914 needed 1 iterations to converge.
# Document 915 needed 1 iterations to converge.
# Document 916 needed 1 iterations to converge.
# Document 917 needed 1 iterations to converge.
# Document 918 needed 1 iterations to converge.
# Document 919 needed 1 iterations to converge.
# Document 920 needed 1 iterations to converge.
# Document 921 needed 1 iterations to converge.
# Document 922 needed 1 iterations to converge.
# Document 923 needed 1 iterations to converge.
# Document 924 needed 1 iterations to converge.
# Document 925 needed 1 iterations to converge.
# Document 926 needed 1 iterations to converge.
# Document 927 needed 1 iterations to converge.
# Document 928 needed 1 iterations to converge.
# Document 929 needed 1 iterations to converge.
# Document 930 needed 1 iterations to converge.
# Document 931 needed 1 iterations to converge.
# Document 932 needed 1 iterations to converge.
# Document 933 needed 1 iterations to converge.
# Document 934 needed 1 iterations to converge.
# Document 935 needed 1 iterations to converge.
# Document 936 needed 1 iterations to converge.
# Document 937 needed 1 iterations to converge.
# Document 938 needed 1 iterations to converge.
# Document 939 needed 1 iterations to converge.
# Document 940 needed 1 iterations to converge.
# Document 941 needed 1 iterations to converge.
# Document 942 needed 1 iterations to converge.
# Document 943 needed 1 iterations to converge.
# Document 944 needed 1 iterations to converge.
# Document 945 needed 1 iterations to converge.
# Document 946 needed 1 iterations to converge.
# Document 947 needed 1 iterations to converge.
# Document 948 needed 1 iterations to converge.
# Document 949 needed 1 iterations to converge.
# Document 950 needed 1 iterations to converge.
# Document 951 needed 1 iterations to converge.
# Document 952 needed 1 iterations to converge.
# Document 953 needed 1 iterations to converge.
# Document 954 needed 1 iterations to converge.
# Document 955 needed 1 iterations to converge.
# Document 956 needed 1 iterations to converge.
# Document 957 needed 1 iterations to converge.
# Document 958 needed 1 iterations to converge.
# Document 959 needed 1 iterations to converge.
# Document 960 needed 1 iterations to converge.
# Document 961 needed 1 iterations to converge.
# Document 962 needed 1 iterations to converge.
# Document 963 needed 1 iterations to converge.
# Document 964 needed 1 iterations to converge.
# Document 965 needed 1 iterations to converge.
# Document 966 needed 1 iterations to converge.
# Document 967 needed 1 iterations to converge.
# Document 968 needed 1 iterations to converge.
# Document 969 needed 1 iterations to converge.
# Document 970 needed 1 iterations to converge.
# Document 971 needed 1 iterations to converge.
# Document 972 needed 1 iterations to converge.
# Document 973 needed 1 iterations to converge.
# Document 974 needed 1 iterations to converge.
# Document 975 needed 1 iterations to converge.
# Document 976 needed 1 iterations to converge.
# Document 977 needed 1 iterations to converge.
# Document 978 needed 1 iterations to converge.
# Document 979 needed 1 iterations to converge.
# Document 980 needed 1 iterations to converge.
# Document 981 needed 1 iterations to converge.
# Document 982 needed 1 iterations to converge.
# Document 983 needed 1 iterations to converge.
# Document 984 needed 1 iterations to converge.
# Document 985 needed 1 iterations to converge.
# Document 986 needed 1 iterations to converge.
# Document 987 needed 1 iterations to converge.
# Document 988 needed 1 iterations to converge.
# Document 989 needed 1 iterations to converge.
# Document 990 needed 1 iterations to converge.
# Document 991 needed 1 iterations to converge.
# Document 992 needed 1 iterations to converge.
# Document 993 needed 1 iterations to converge.
# Document 994 needed 1 iterations to converge.
# Document 995 needed 1 iterations to converge.
# Document 996 needed 1 iterations to converge.
# Document 997 needed 1 iterations to converge.
# Document 998 needed 1 iterations to converge.
# Document 999 needed 1 iterations to converge.
# M-step
# Iteration 2: Likelihood = 3583.5189384561095
