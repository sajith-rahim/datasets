# %%
import numpy as np
from sklearn.naive_bayes import BernoulliNB

# %%
X = np.random.randint(2,size=(1000,9))
Y = np.array(list(range(1000)))

# %%
Y.shape
# Out:
# (1000,)

# %%
nb = BernoulliNB()
nb.fit(X,Y)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
xq = np.array([0, 0, 0, 1, 1, 1, 1, 0, 1]).reshape(1,9)

# %%
nb.predict(xq)
# Out:
# array([42])
